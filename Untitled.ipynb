# %%
import pandas as pd
import numpy as np
df = pd.read_csv('고령자 데이터 합 20221220.csv', encoding='cp949')
df = df.set_index('Unnamed: 0', drop=True)

# %%
new_df = df.iloc[12:-1]
new_df['코로나 확진자 수'] = new_df['코로나 확진자 수'].fillna(0)
new_df['65세 이상 자진반납 현황'] = new_df['65세 이상 자진반납 현황'].fillna(0)
new_df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19244\30251210.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['코로나 확진자 수'] = new_df['코로나 확진자 수'].fillna(0)
# C:\Users\user\AppData\Local\Temp\ipykernel_19244\30251210.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['65세 이상 자진반납 현황'] = new_df['65세 이상 자진반납 현황'].fillna(0)
#             65세 이상 경제활동인구 (천 명)  65세 이상 경제활동참가율 (%)  65세 이상 고용률 (%)  \
# Unnamed: 0
# 2011                      238.0                24.5            23.6
# 2012                      263.0                25.6            24.7
# 2013                      276.0                25.4            24.8
# 2014                      318.0                27.7            27.0
# 2015                      322.0                26.7            25.9
# 2016                      326.0                26.3            25.7
# 2017                      345.0                26.7            25.7
# 2018                      356.0                26.5            25.4
# 2019                      410.0                29.3            28.0
# 2020                      433.0                29.3            27.8
# 2021                      434.0                27.9            26.0
#
#             65세 이상 비경제활동인구 (천 명)  65세 인구 (천 명)  취업자 수 (천 명)       총인구 수  \
# Unnamed: 0
# 2011                       732.0         970.0        229.0  10,249,679
# 2012                       765.0        1028.0        254.0  10,195,318
# 2013                       813.0        1089.0        271.0  10,143,645
# 2014                       831.0        1149.0        310.0  10,103,233
# 2015                       883.0        1205.0        313.0  10,022,181
# 2016                       915.0        1241.0        319.0   9,930,616
# 2017                       947.0        1292.0        332.0   9,857,426
# 2018                       990.0        1346.0        343.0   9,765,623
# 2019                       990.0        1400.0        393.0   9,729,107
# 2020                      1046.0        1479.0        412.0   9,668,465
# 2021                      1121.0        1555.0        411.0   9,509,458
#
#             서울 주유비 (원)  65세 이상 질병 사망자 수  65세 이상 자진반납 현황  경제성장률 (%)  코로나 확진자 수  \
# Unnamed: 0
# 2011           1995.59            156.0             0.0        3.7        0.0
# 2012           2058.96            154.0             0.0        2.4        0.0
# 2013           2002.96            179.0             0.0        3.2        0.0
# 2014           1914.95            193.0             0.0        3.2        0.0
# 2015           1596.74            220.0           348.0        2.8        0.0
# 2016           1499.82            196.0           447.0        2.9        0.0
# 2017           1589.52            264.0           799.0        3.2        0.0
# 2018           1670.03            307.0          1387.0        2.9        0.0
# 2019           1567.52            360.0         17393.0        2.2        0.0
# 2020           1470.37            382.0         14296.0       -0.7    60726.0
# 2021           1668.46            408.0         15391.0        4.1   570057.0
#
#             65세 이상 사망자 수
# Unnamed: 0
# 2011             23762.0
# 2012             24983.0
# 2013             25345.0
# 2014             25598.0
# 2015             26509.0
# 2016             26885.0
# 2017             26642.0
# 2018             28473.0
# 2019             27491.0
# 2020             28786.0
# 2021             31218.0

# %%
new_df['총인구 수'] = new_df['총인구 수'].str.replace(',','').astype('int64')

for i in range(0, 13):
    new_df.iloc[:,i] = new_df.iloc[:,i].astype('int64')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19244\2907641605.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['총인구 수'] = new_df['총인구 수'].str.replace(',','').astype('int64')
# C:\Users\user\AppData\Local\Temp\ipykernel_19244\2907641605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.iloc[:,i] = new_df.iloc[:,i].astype('int64')

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 2011 to 2021
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   65세 이상 경제활동인구 (천 명)   11 non-null     int64
#  1   65세 이상 경제활동참가율 (%)    11 non-null     int64
#  2   65세 이상 고용률 (%)        11 non-null     int64
#  3   65세 이상 비경제활동인구 (천 명)  11 non-null     int64
#  4   65세 인구 (천 명)          11 non-null     int64
#  5   취업자 수 (천 명)           11 non-null     int64
#  6   총인구 수                 11 non-null     int64
#  7   서울 주유비 (원)            11 non-null     int64
#  8   65세 이상 질병 사망자 수       11 non-null     int64
#  9   65세 이상 자진반납 현황        11 non-null     int64
#  10  경제성장률 (%)             11 non-null     int64
#  11  코로나 확진자 수             11 non-null     int64
#  12  65세 이상 사망자 수          11 non-null     int64
# dtypes: int64(13)
# memory usage: 1.2 KB

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imputer = IterativeImputer(random_state=0)
mm_df = imputer.fit_transform(new_df)
len(mm_df)
# Out:
# 11

# %%
# 결측치 비율 확인
for col in new_df.columns:
    na = 'column: {:>10}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (new_df[col].isnull().sum() / df[col].shape[0]))
    print(na)
# Out:
# column: 65세 이상 경제활동인구 (천 명)	 Percent of NaN value: 0.00%
# column: 65세 이상 경제활동참가율 (%)	 Percent of NaN value: 0.00%
# column: 65세 이상 고용률 (%)	 Percent of NaN value: 0.00%
# column: 65세 이상 비경제활동인구 (천 명)	 Percent of NaN value: 0.00%
# column: 65세 인구 (천 명)	 Percent of NaN value: 0.00%
# column: 취업자 수 (천 명)	 Percent of NaN value: 0.00%
# column:      총인구 수	 Percent of NaN value: 0.00%
# column: 서울 주유비 (원)	 Percent of NaN value: 0.00%
# column: 65세 이상 질병 사망자 수	 Percent of NaN value: 0.00%
# column: 65세 이상 자진반납 현황	 Percent of NaN value: 16.67%
# column:  경제성장률 (%)	 Percent of NaN value: 0.00%
# column:  코로나 확진자 수	 Percent of NaN value: 0.00%
# column: 65세 이상 사망자 수	 Percent of NaN value: 0.00%

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
